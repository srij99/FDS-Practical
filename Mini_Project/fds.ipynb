# %%
import pandas as pd
import seaborn as sns

# %%
a= pd.read_csv('C:/Users/sreej/OneDrive/Desktop/fds dataset/heart.csv')
a.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             179 non-null    int64
#  1   Sex             179 non-null    object
#  2   ChestPainType   179 non-null    object
#  3   RestingBP       179 non-null    int64
#  4   Cholesterol     179 non-null    int64
#  5   FastingBS       179 non-null    int64
#  6   RestingECG      179 non-null    object
#  7   MaxHR           179 non-null    int64
#  8   ExerciseAngina  179 non-null    object
#  9   Oldpeak         179 non-null    float64
#  10  ST_Slope        179 non-null    object
#  11  HeartDisease    179 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 16.9+ KB

# %%
sns.barplot(a['Age'],a['RestingBP'])
# Out:
# C:\Users\sreej\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='RestingBP'>

# %%
sns.distplot(a['Cholesterol'])
# Out:
# C:\Users\sreej\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Cholesterol', ylabel='Density'>

# %%
sns.pairplot(a[['Age','RestingBP','MaxHR']])

# %%
sns.barplot(a['Age'],a['Cholesterol'])
# Out:
# C:\Users\sreej\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Cholesterol'>

# %%
sns.countplot(a['ChestPainType'])
# Out:
# C:\Users\sreej\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(a['HeartDisease'])
# Out:
# C:\Users\sreej\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>
